# %%
from deep_cluster import DeepCluster
from deep_latent import DeepLatentCluster

# %%
stop
# to prevent the notebook from running the rest of the cell
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Will\Projects\MSc\project\src\pds_notebook.ipynb Cell 2 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Will/Projects/MSc/project/src/pds_notebook.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> stop
#
# NameError: name 'stop' is not defined

# %% [markdown]
# ## Baseline

# %%
dc = DeepCluster(
        'test-0-40latent',
        dims=[768, 500, 500, 2000, 40],
        entity_count=10,
        train_size=0,
        num_clusters=25,
        maxiter=2000)
dc.make_load_model()
dc.evaluate_model(10000, verbose=0)
# Out:
# model compiled
# Loading AE weights from ./results/test-0-40latent\jae_weights.h5
# Loading model weights from ./results/test-0-40latent\DEC_model_final.h5
# Creating _test data
# Reusing dataset conll2003 (C:\Users\Will\.cache\huggingface\datasets\conll2003\conll2003\1.0.0\9a4d16a94f8674ba3466315300359b0acd891b68b6c8743ddf60b9c702adce98)
#   0%|          | 0/3 [00:00<?, ?it/s]
# Reading lines
# 100%|██████████| 3453/3453 [00:00<00:00, 690946.60it/s]
# pre-embedding all
# Finished 'get_pipe' in 7.998 secs
# 100%|██████████| 3453/3453 [05:36<00:00, 10.25it/s]
# Emedded 3453 sentences
# Saved to ./data\conll_n10000_test
# Embedding sentences radius 6
# 3453it [00:10, 328.70it/s]
# Finished 'get_training_data_spacy' in 356.872 secs
# SAVED ./data/conll_spacy_n10000_r6_test.pkl
# #GPE:7 size:32 prec:1.0000 rec:0.0148 f1:0.0292
# #PERSON:11 size:2008 prec:1.0000 rec:0.6301 f1:0.7731
# #ORG:2 size:1002 prec:1.0000 rec:0.1687 f1:0.2887
# #DATE:15 size:120 prec:1.0000 rec:0.0656 f1:0.1231
# #UNK-GPE-4:4 size:1633 prec:1.0000 rec:0.1443 f1:0.2523
# #NORP:17 size:13 prec:1.0000 rec:0.0026 f1:0.0051
# #UNK-PERSON-6:1 size:1858 prec:1.0000 rec:0.4368 f1:0.6080
# #UNK-GPE-7:0 size:77 prec:1.0000 rec:0.0192 f1:0.0377
# #UNK-ORG-8:8 size:2137 prec:1.0000 rec:0.1630 f1:0.2803
# #UNK-DATE-9:3 size:147 prec:1.0000 rec:0.0236 f1:0.0460
# #UNK-GPE-10:10 size:101 prec:1.0000 rec:0.0104 f1:0.0206
# #UNK-PERSON-11:6 size:809 prec:1.0000 rec:0.3773 f1:0.5479
# #CARDINAL:12 size:208 prec:1.0000 rec:0.0630 f1:0.1185
# #MONEY:13 size:66 prec:1.0000 rec:0.1351 f1:0.2381
# #UNK-DATE-15:9 size:434 prec:1.0000 rec:0.0898 f1:0.1648
# #UNK-GPE-16:16 size:1206 prec:1.0000 rec:0.2161 f1:0.3553
# #UNK-NORP-17:5 size:65 prec:1.0000 rec:0.0101 f1:0.0201
# #EVENT:18 size:24 prec:1.0000 rec:0.0278 f1:0.0541
# #UNK-GPE-19:19 size:698 prec:1.0000 rec:0.0528 f1:0.1003
# #UNK-GPE-20:20 size:1328 prec:1.0000 rec:0.1194 f1:0.2133
# #UNK-GPE-21:21 size:384 prec:1.0000 rec:0.1051 f1:0.1902
# #LOC:22 size:20 prec:1.0000 rec:0.0274 f1:0.0533
# #UNK-DATE-23:23 size:62 prec:1.0000 rec:0.0087 f1:0.0172
# #UNK-DATE-24:24 size:13 prec:1.0000 rec:0.0044 f1:0.0087
#
# F1 by Known Clusters: 0.2440
# F1 score (macro) = 0.1868
# Accuracy = 0.7691
# Precision = 0.5126
# Recall = 0.1537
# New clusters = 2
# ... wrote results to c:\Users\Will\Projects\MSc\project\src\results\test-0-40latent\index.html
# {'f1': 0.18681529828630042,
#  'acc': 0.7690550363447559,
#  'precision': 0.5126051110910183,
#  'recall': 0.15370758526424383,
#  'new_clusters': 2,
#  'cluster F1': 0.24398329282511622}

# %% [markdown]
# ## PDFs on default pre-trained model

# %%
dc = DeepCluster(
        'test-0-40latent',
        dims=[768, 500, 500, 2000, 40],
        entity_count=10,
        train_size=0,
        num_clusters=25,
        maxiter=2000)
dc.make_load_model()
dc.evaluate_model(10000, verbose=1, folder="pdfs/lines.txt", output="test-pdf-untrained")
# Out:
# model compiled
# Loading AE weights from ./results/test-0-40latent\jae_weights.h5
# Loading model weights from ./results/test-0-40latent\DEC_model_final.h5
# Load Data
# Loading ./pdfs/lines.txt_n10000_r0_test.pkl
# LOADED {1: 'UNKNOWN', 17: 'CARDINAL', 5: 'GPE', 4: 'ORG', 2: 'PERSON', 11: 'DATE', 7: 'PRODUCT', 16: 'ORDINAL', 3: 'NORP', 14: 'MONEY', 13: 'PERCENT', 9: 'WORK_OF_ART', 18: 'FAC', 12: 'TIME', 6: 'LOC', 15: 'QUANTITY', 8: 'EVENT', 10: 'LAW'}
# Loaded file: 59202 samples
# Data balance:
# [[    1 48445]
#  [    2  1448]
#  [    3   224]
#  [    4  4236]
#  [    5   669]
#  [    6   142]
#  [    7   160]
#  [    8    26]
#  [    9    70]
#  [   10    28]
#  [   11   553]
#  [   12    99]
#  [   13    87]
#  [   14    34]
#  [   15   119]
#  [   16   218]
#  [   17  2420]
#  [   18    40]]
# x: (59018, 768), y: (59018,)
# {0: 'UNKNOWN', 1: 'PERSON', 2: 'NORP', 3: 'ORG', 4: 'GPE', 5: 'LOC', 6: 'PRODUCT', 7: 'EVENT', 8: 'WORK_OF_ART', 9: 'LAW', 10: 'DATE', 11: 'TIME', 12: 'PERCENT', 13: 'MONEY', 14: 'QUANTITY', 15: 'ORDINAL', 16: 'CARDINAL', 17: 'FAC'}
# Data Loaded
# model compiled
# Loading AE weights from ./results/test-0-40latent\jae_weights.h5
# Loading model weights from ./results/test-0-40latent\DEC_model_final.h5
# Predicting
# Predicted
# CLUSTERS
# #ORG:21 size:700 prec:1.0000 rec:0.1739 f1:0.2962
# #UNK-ORG-1:0 size:2568 prec:1.0000 rec:0.1483 f1:0.2583
# #UNK-ORG-2:2 size:13997 prec:1.0000 rec:0.6579 f1:0.7937
# #UNK-ORG-3:3 size:1530 prec:1.0000 rec:0.1322 f1:0.2336
# #CARDINAL:18 size:6 prec:1.0000 rec:0.0006 f1:0.0012
# #UNK-ORG-5:5 size:400 prec:1.0000 rec:0.0227 f1:0.0444
# #UNK-ORG-6:6 size:734 prec:1.0000 rec:0.1098 f1:0.1979
# #GPE:7 size:6 prec:1.0000 rec:0.0030 f1:0.0060
# #UNK-ORG-8:8 size:18455 prec:1.0000 rec:0.5656 f1:0.7225
# #UNK-CARDINAL-9:4 size:482 prec:1.0000 rec:0.0157 f1:0.0309
# #UNK-ORG-10:10 size:1631 prec:1.0000 rec:0.1223 f1:0.2179
# #PERSON:11 size:3399 prec:1.0000 rec:0.3038 f1:0.4661
# #UNK-CARDINAL-12:9 size:2670 prec:1.0000 rec:0.1310 f1:0.2316
# #UNK-CARDINAL-13:12 size:1183 prec:1.0000 rec:0.0819 f1:0.1515
# #DATE:15 size:25 prec:1.0000 rec:0.0057 f1:0.0114
# #UNK-PERSON-16:16 size:138 prec:1.0000 rec:0.0128 f1:0.0254
# #UNK-ORG-17:17 size:74 prec:1.0000 rec:0.0058 f1:0.0115
# #UNK-CARDINAL-18:13 size:1216 prec:1.0000 rec:0.1024 f1:0.1858
# #UNK-ORG-19:19 size:4915 prec:1.0000 rec:0.2770 f1:0.4339
# #UNK-ORG-20:20 size:525 prec:1.0000 rec:0.0350 f1:0.0677
# #UNK-ORG-21:1 size:3287 prec:1.0000 rec:0.4029 f1:0.5744
# #UNK-CARDINAL-22:22 size:26 prec:1.0000 rec:0.0012 f1:0.0024
# #UNK-DATE-23:23 size:299 prec:1.0000 rec:0.0545 f1:0.1034
# #UNK-CARDINAL-24:24 size:752 prec:1.0000 rec:0.0553 f1:0.1048
#
# F1 by Known Clusters: 0.5285
# F1 score (macro) = 0.1616
# Accuracy = 0.9015
# Precision = 0.3274
# Recall = 0.1395
# New clusters =      1
# ... wrote results to c:\Users\Will\Projects\MSc\project\src\results\test-pdf-untrained\index.html
# {'f1': 0.16163047670362862,
#  'acc': 0.9014876817242198,
#  'precision': 0.32738040386541095,
#  'recall': 0.1394955506608716,
#  'new_clusters': 1,
#  'cluster F1': 0.5284917503042831}

# %% [markdown]
# ## PDFs retrained

# %%
dc = DeepCluster(
        'test-pdfs-dec',
        dims=[768, 500, 500, 2000, 40],
        entity_count=10,
        train_size=0,
        num_clusters=25,
        maxiter=2000)
dc.train_and_evaluate_model(10000, verbose=1, folder="pdfs/lines.txt")
# Out:
# model compiled
# Load Data
# Loading ./pdfs/lines.txt_n0_r0.pkl
# LOADED {1: 'UNKNOWN', 17: 'CARDINAL', 5: 'GPE', 4: 'ORG', 2: 'PERSON', 11: 'DATE', 7: 'PRODUCT', 16: 'ORDINAL', 3: 'NORP', 14: 'MONEY', 13: 'PERCENT', 9: 'WORK_OF_ART', 18: 'FAC', 12: 'TIME', 6: 'LOC', 15: 'QUANTITY', 8: 'EVENT', 10: 'LAW'}
# Loaded file: 10543 samples
# Data balance:
# [[   2 2521]
#  [   3  328]
#  [   4 5372]
#  [   5 1107]
#  [   6  151]
#  [  11  640]
#  [  12  119]
#  [  13  104]
#  [  14   35]
#  [  15  133]]
# Balancing data
# Post Oversampling
# x: (53720, 768), y: (53720,)
# {0: 'PERSON', 1: 'NORP', 2: 'ORG', 3: 'GPE', 4: 'LOC', 5: 'DATE', 6: 'TIME', 7: 'PERCENT', 8: 'MONEY', 9: 'QUANTITY'}
# Data Loaded
# Data Loaded
# model compiled
# Training autoencoder
# Epoch 37: early stopping
# Trained autoencoder
# cluster init
# 4/4 [==============================] - 0s 1ms/step
# cluster init done
# Iter: 0 Acc = 0.27638, nmi = 0.20905, ari = 0.10225 ; loss=0
# Iter: 140 Acc = 0.27157, nmi = 0.21562, ari = 0.10875 ; loss=[0.02301 0.01732 0.00569]
# Iter: 280 Acc = 0.26491, nmi = 0.21848, ari = 0.10751 ; loss=[0.03575 0.02106 0.01469]
# Iter: 420 Acc = 0.25164, nmi = 0.21648, ari = 0.09823 ; loss=[0.04313 0.02758 0.01554]
# Iter: 560 Acc = 0.24505, nmi = 0.21773, ari = 0.09546 ; loss=[0.08407 0.05913 0.02494]
# Iter: 700 Acc = 0.24244, nmi = 0.21590, ari = 0.09751 ; loss=[0.12995 0.07975 0.0502 ]
# Iter: 840 Acc = 0.24213, nmi = 0.20768, ari = 0.09307 ; loss=[0.15893 0.12469 0.03424]
# Iter: 980 Acc = 0.23943, nmi = 0.20527, ari = 0.09340 ; loss=[0.20652 0.16613 0.04039]
# Iter: 1120 Acc = 0.23753, nmi = 0.20565, ari = 0.09473 ; loss=[0.21547 0.14706 0.06841]
# Iter: 1260 Acc = 0.23697, nmi = 0.20841, ari = 0.09239 ; loss=[0.14767 0.1094  0.03827]
# Iter: 1400 Acc = 0.23704, nmi = 0.21032, ari = 0.09416 ; loss=[0.0891  0.04628 0.04282]
# Iter: 1540 Acc = 0.23749, nmi = 0.21048, ari = 0.09442 ; loss=[0.16484 0.08847 0.07638]
# Iter: 1680 Acc = 0.23894, nmi = 0.20891, ari = 0.09470 ; loss=[0.11121 0.07131 0.0399 ]
# Iter: 1820 Acc = 0.23578, nmi = 0.20820, ari = 0.09384 ; loss=[0.07633 0.0319  0.04444]
# Iter: 1960 Acc = 0.22904, nmi = 0.20550, ari = 0.08869 ; loss=[0.1337  0.05729 0.07641]
# Training Done
# Load Data
# Loading ./pdfs/lines.txt_n10000_r0_test.pkl
# LOADED {1: 'UNKNOWN', 17: 'CARDINAL', 5: 'GPE', 4: 'ORG', 2: 'PERSON', 11: 'DATE', 7: 'PRODUCT', 16: 'ORDINAL', 3: 'NORP', 14: 'MONEY', 13: 'PERCENT', 9: 'WORK_OF_ART', 18: 'FAC', 12: 'TIME', 6: 'LOC', 15: 'QUANTITY', 8: 'EVENT', 10: 'LAW'}
# Loaded file: 59202 samples
# Data balance:
# [[    1 48445]
#  [    2  1448]
#  [    3   224]
#  [    4  4236]
#  [    5   669]
#  [    6   142]
#  [    7   160]
#  [    8    26]
#  [    9    70]
#  [   10    28]
#  [   11   553]
#  [   12    99]
#  [   13    87]
#  [   14    34]
#  [   15   119]
#  [   16   218]
#  [   17  2420]
#  [   18    40]]
# x: (59018, 768), y: (59018,)
# {0: 'UNKNOWN', 1: 'PERSON', 2: 'NORP', 3: 'ORG', 4: 'GPE', 5: 'LOC', 6: 'PRODUCT', 7: 'EVENT', 8: 'WORK_OF_ART', 9: 'LAW', 10: 'DATE', 11: 'TIME', 12: 'PERCENT', 13: 'MONEY', 14: 'QUANTITY', 15: 'ORDINAL', 16: 'CARDINAL', 17: 'FAC'}
# Data Loaded
# model compiled
# Loading AE weights from ./results/test-pdfs-dec\jae_weights.h5
# Loading model weights from ./results/test-pdfs-dec\DEC_model_final.h5
# Predicting
# Predicted
# CLUSTERS
# #CARDINAL:1 size:227 prec:1.0000 rec:0.1055 f1:0.1909
# #UNK-CARDINAL-1:0 size:949 prec:1.0000 rec:0.0852 f1:0.1570
# #ORG:6 size:4482 prec:1.0000 rec:0.6198 f1:0.7653
# #UNK-ORG-3:3 size:598 prec:1.0000 rec:0.0755 f1:0.1404
# #UNK-ORG-4:4 size:2030 prec:1.0000 rec:0.1329 f1:0.2347
# #UNK-CARDINAL-5:5 size:1109 prec:1.0000 rec:0.1660 f1:0.2847
# #UNK-ORG-6:2 size:1438 prec:1.0000 rec:0.1837 f1:0.3103
# #UNK-CARDINAL-7:7 size:841 prec:1.0000 rec:0.0311 f1:0.0603
# #UNK-ORG-8:8 size:11153 prec:1.0000 rec:0.4361 f1:0.6073
# #UNK-ORG-9:9 size:17071 prec:1.0000 rec:0.5549 f1:0.7137
# #UNK-ORG-10:10 size:2499 prec:1.0000 rec:0.2866 f1:0.4455
# #UNK-ORG-11:11 size:1723 prec:1.0000 rec:0.3678 f1:0.5378
# #UNK-ORG-12:12 size:1308 prec:1.0000 rec:0.1489 f1:0.2593
# #UNK-CARDINAL-13:13 size:1907 prec:1.0000 rec:0.2280 f1:0.3713
# #UNK-ORG-14:14 size:275 prec:1.0000 rec:0.0551 f1:0.1045
# #UNK-ORG-15:15 size:3669 prec:1.0000 rec:0.2718 f1:0.4275
# #UNK-ORG-16:16 size:538 prec:1.0000 rec:0.1513 f1:0.2629
# #PERSON:17 size:2162 prec:1.0000 rec:0.2576 f1:0.4097
# #UNK-ORG-18:18 size:1198 prec:1.0000 rec:0.1098 f1:0.1979
# #UNK-CARDINAL-19:19 size:1348 prec:1.0000 rec:0.0951 f1:0.1737
# #UNK-CARDINAL-20:20 size:1463 prec:1.0000 rec:0.0838 f1:0.1547
# #UNK-CARDINAL-21:21 size:103 prec:1.0000 rec:0.0080 f1:0.0158
# #DATE:22 size:102 prec:1.0000 rec:0.1266 f1:0.2247
# #MONEY:23 size:1 prec:1.0000 rec:0.0294 f1:0.0571
# #UNK-ORG-24:24 size:824 prec:1.0000 rec:0.0551 f1:0.1045
#
# F1 by Known Clusters: 0.4421
# F1 score (macro) = 0.1787
# Accuracy = 0.9099
# Precision = 0.3278
# Recall = 0.1532
# New clusters = 0
# ... wrote results to c:\Users\Will\Projects\MSc\project\src\results\test-pdfs-dec\index.html

# %% [markdown]
# ## PDFs via latent model

# %%
# %%time
# benchmark with cluster rearrangement
from deep_latent import DeepLatentCluster
from cluster_metrics import summarise_scores

dc = None
dc = DeepLatentCluster(
    'test-latent-15-ents-lw0.5-rw1.0-z-Kmeans',
    {
        'train_size':0,
        "cluster": "Kmeans"
    })
score = dc.evaluate_model(
        'test-latent-15-ents-lw0.5-rw1.0-z-Kmeans', 
        sample_size=10000,
        verbose=0,
        folder="pdfs/lines.txt",
        output="test-pdf-latent")

summarise_scores([{**score, "run_name": "latent-bm"}])
# Out:
# c:\Users\Will\Anaconda3\envs\tf-27\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# c:\Users\Will\Anaconda3\envs\tf-27\lib\site-packages\sklearn\utils\validation.py:1858: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   warnings.warn(
# c:\Users\Will\Projects\MSc\project\src\deep_latent.py:574: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   z_space = np.vstack(np.array(z_sample)) # type: ignore
# #NORP:15 size:273 prec:1.0000 rec:0.1495 f1:0.2600
# #LOC:9 size:85 prec:1.0000 rec:0.1120 f1:0.2015
# #LAW:2 size:281 prec:1.0000 rec:1.0000 f1:1.0000
# #GPE:3 size:819 prec:1.0000 rec:0.3234 f1:0.4888
# #MONEY:4 size:570 prec:1.0000 rec:0.4760 f1:0.6450
# #ORDINAL:5 size:366 prec:1.0000 rec:0.3216 f1:0.4867
# #UNK-LOC-6:6 size:477 prec:1.0000 rec:0.2559 f1:0.4075
# #QUANTITY:7 size:253 prec:1.0000 rec:0.2230 f1:0.3647
# #TIME:8 size:534 prec:1.0000 rec:0.3963 f1:0.5676
# #UNK-LOC-9:1 size:397 prec:1.0000 rec:0.2324 f1:0.3772
# #PERCENT:10 size:627 prec:1.0000 rec:0.6027 f1:0.7521
# #LANGUAGE:20 size:93 prec:1.0000 rec:0.4457 f1:0.6165
# #EVENT:21 size:252 prec:1.0000 rec:0.5178 f1:0.6823
# #FAC:13 size:342 prec:1.0000 rec:0.1320 f1:0.2333
# #PERSON:14 size:271 prec:1.0000 rec:0.1149 f1:0.2060
# #UNK-NORP-15:0 size:288 prec:1.0000 rec:0.1476 f1:0.2572
# #DATE:16 size:419 prec:1.0000 rec:0.3528 f1:0.5216
# #UNK-LANGUAGE-17:11 size:360 prec:1.0000 rec:0.5234 f1:0.6871
# #UNK-LAW-18:18 size:1032 prec:1.0000 rec:1.0000 f1:1.0000
# #PRODUCT:19 size:754 prec:1.0000 rec:0.1602 f1:0.2762
# #UNK-LANGUAGE-20:17 size:360 prec:1.0000 rec:0.6611 f1:0.7960
# #UNK-EVENT-21:12 size:536 prec:1.0000 rec:0.5962 f1:0.7470
# #UNK-PERCENT-22:22 size:340 prec:1.0000 rec:0.4286 f1:0.6000
# #WORK_OF_ART:23 size:73 prec:1.0000 rec:0.1237 f1:0.2202
# #UNK-WORK_OF_ART-24:24 size:198 prec:1.0000 rec:0.1818 f1:0.3077
#
# F1 by Known Clusters: 0.2649
# c:\Users\Will\Anaconda3\envs\tf-27\lib\site-packages\sklearn\metrics\_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# F1 score (macro) = 0.4690
# Accuracy = 0.4023
# Precision = 0.8461
# Recall = 0.4036
# New clusters = 3
# ... wrote results to c:\Users\Will\Projects\MSc\project\src\results\test-pdf-latent\index.html
# Finished 'evaluate_model' in 40.8 secs
# Run Name                                 Runs       F1 avg       F1 Cluster   F1 Global    Precision    Recall
# latent-bm                                1           0.3670       0.2649       0.4690      0.8461       0.4036
# CPU times: total: 4min 15s
# Wall time: 40.8 s
